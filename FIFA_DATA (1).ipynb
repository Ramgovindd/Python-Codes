# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
df = pd.read_csv('/content/FIFA_data.csv')

# %%
df.hist(color='y',alpha=0.8,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3a33876d10>,
# ...
#       dtype=object)

# %%
df['Balance'].plot(kind='hist')

# %%
df.plot(kind='hist')

# %%
df_new= df.head(1000)

# %%
df_new.plot(kind='bar')

# %%
df_new.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
new=df_new.drop(['Name','Photo','Nationality','Flag','Club','Club Logo','Value','Wage','Body Type','Work Rate','Position','Preferred Foot','Real Face','Joined','Loaned From','Weight','Height','Release Clause','LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB','Contract Valid Until'],axis=1)

# %%
new.head()
# Out:
#    Unnamed: 0      ID  Age  ...  GKKicking  GKPositioning  GKReflexes
# 0           0  158023   31  ...       15.0           14.0         8.0
# 1           1   20801   33  ...       15.0           14.0        11.0
# 2           2  190871   26  ...       15.0           15.0        11.0
# 3           3  193080   27  ...       87.0           88.0        94.0
# 4           4  192985   27  ...        5.0           10.0        13.0
#
# [5 rows x 44 columns]

# %%
df1=new.head(20)

# %%
df1.plot.pie(subplots=True,figsize=(25,25),fontsize=20)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ecf214310>,
# ...
#       dtype=object)
